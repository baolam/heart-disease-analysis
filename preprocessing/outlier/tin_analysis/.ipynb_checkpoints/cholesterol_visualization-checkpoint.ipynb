# %%
import pandas as pd
import json
from matplotlib import pyplot as plt
import geopandas as gpd
import numpy as np

# %%
df = pd.read_csv('../../../data/csv/cholesterol.csv')
indicators = df['IndicatorCode'].unique()
print(indicators)
df
# Out:
# ['NCD_CHOL_MEANHDL_A' 'NCD_CHOL_MEANHDL_C' 'NCD_CHOL_MEANNONHDL_A'
#  'NCD_CHOL_MEANNONHDL_C' 'NCD_CHOL_MEANTOTALCHOL_A'
#  'NCD_CHOL_MEANTOTALCHOL_C']
#         Unnamed: 0 ParentLocationCode SpatialDim      Dim1          Value  \
# 0                0                AFR        SWZ   SEX_MLE  1.2 [1.0-1.3]
# 1                1                EUR        ARM  SEX_BTSX  1.0 [0.9-1.2]
# 2                2                AFR        TGO  SEX_FMLE  1.1 [0.8-1.4]
# 3                3                AFR        CAF  SEX_FMLE  1.1 [0.8-1.4]
# 4                4                EUR        TJK   SEX_MLE  1.1 [0.9-1.3]
# ...            ...                ...        ...       ...            ...
# 141799      141799                EMR        KWT   SEX_MLE  5.2 [4.8-5.6]
# 141800      141800                EMR        AFG   SEX_MLE  4.1 [3.8-4.5]
# 141801      141801                EUR        NLD   SEX_MLE  5.4 [5.2-5.5]
# 141802      141802                WPR        MYS  SEX_BTSX  4.6 [4.3-5.0]
# 141803      141803                AMR        URY  SEX_BTSX  4.9 [4.7-5.1]
#
#         NumericValue                       Date             IndicatorCode
# 0                1.2  2021-06-21T18:40:56+02:00        NCD_CHOL_MEANHDL_A
# 1                1.0  2021-06-21T19:07:07+02:00        NCD_CHOL_MEANHDL_A
# 2                1.1  2021-06-21T19:00:54+02:00        NCD_CHOL_MEANHDL_A
# 3                1.1  2021-06-21T18:58:44+02:00        NCD_CHOL_MEANHDL_A
# 4                1.1  2021-06-21T18:40:59+02:00        NCD_CHOL_MEANHDL_A
# ...              ...                        ...                       ...
# 141799           5.2  2021-06-21T18:24:07+02:00  NCD_CHOL_MEANTOTALCHOL_C
# 141800           4.1  2021-06-21T18:22:29+02:00  NCD_CHOL_MEANTOTALCHOL_C
# 141801           5.4  2021-06-21T18:24:41+02:00  NCD_CHOL_MEANTOTALCHOL_C
# 141802           4.6  2021-06-21T19:11:15+02:00  NCD_CHOL_MEANTOTALCHOL_C
# 141803           4.9  2021-06-21T19:12:22+02:00  NCD_CHOL_MEANTOTALCHOL_C
#
# [141804 rows x 8 columns]

# %%
# remove null value
print(len(df))
df=df.dropna(subset=['NumericValue'])
print(len(df))
print(df["NumericValue"].isnull().sum())
# Out:
# 141804
# 141804
# 0

# %%
plt.figure()
plt.scatter(df['IndicatorCode'], df['NumericValue'])
plt.xlabel('IndicatorCode')
plt.ylabel('NumericValue')
plt.title('Scatter Plot of Cholesterol')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(10,5))

codes = df['IndicatorCode'].unique()
data = [df[df['IndicatorCode'] == c]['NumericValue'] for c in codes]

plt.boxplot(data, labels=codes)
#plt.xticks(rotation=45)
plt.title('NumericValue by IndicatorCode')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\lam01\AppData\Local\Temp\ipykernel_17596\2890682797.py:6: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(data, labels=codes)

# %%
# ==============================
# 1. KIỂM TRA & CHUẨN HÓA (Đã sửa lỗi Mixed Timezones)
# ==============================
df1 = df[df['IndicatorCode'] == 'NCD_CHOL_MEANNONHDL_A']
df1["NumericValue"] = pd.to_numeric(df1["NumericValue"], errors="coerce")

# Thêm utc=True để xử lý các múi giờ khác nhau
df1["Date"] = pd.to_datetime(df1["Date"], errors="coerce", utc=True)

# ==============================
# 2. GỘP DỮ LIỆU & TÍNH LOG
# ==============================
df_grouped = (
    df1.groupby(
        ["SpatialDim", "ParentLocationCode"],
        as_index=False
    )
    .agg(
        MeanValue=("NumericValue", "mean"),
        Count=("NumericValue", "count")
    )
)

# Tạo cột LogMeanValue: log1p(x) = log(1 + x)
# Việc cộng 1 giúp tránh lỗi nếu MeanValue bằng 0
df_grouped["LogMeanValue"] = np.log1p(df_grouped["MeanValue"])

# ==============================
# 3. LOAD BẢN ĐỒ & MERGE
# ==============================
world = gpd.read_file("../../../worldmap/ne_110m_admin_0_countries.shp")

gdf = world.merge(
    df_grouped,
    how="left",
    left_on="ISO_A3",
    right_on="SpatialDim"
)

# ==============================
# 4. VẼ BẢN ĐỒ VỚI THANG LOG
# ==============================
fig, ax = plt.subplots(figsize=(16, 9))

# Sử dụng cột "LogMeanValue" để vẽ màu
gdf.plot(
    column="LogMeanValue", 
    ax=ax,
    legend=True,
    cmap="YlOrRd",
    edgecolor="black",
    linewidth=0.3,
    legend_kwds={
        'label': "Log Scale của Giá trị Trung bình (log1p)",
        'orientation': "horizontal",
        'pad': 0.05
    },
    missing_kwds={
        "color": "lightgrey",
        "label": "No data"
    }
)

ax.set_title(
    "Bản đồ nhiệt: Log(Giá trị Nồng độ Non-HDL cholesterol trung bình ở người trưởng thành) theo quốc gia", 
    fontsize=16, 
    pad=20
)

ax.axis("off")
plt.show()
# Out:
# C:\Users\lam01\AppData\Local\Temp\ipykernel_17596\3451030871.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["NumericValue"] = pd.to_numeric(df1["NumericValue"], errors="coerce")
# C:\Users\lam01\AppData\Local\Temp\ipykernel_17596\3451030871.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["Date"] = pd.to_datetime(df1["Date"], errors="coerce", utc=True)
