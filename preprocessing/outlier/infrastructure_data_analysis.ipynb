# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# %%
df = pd.read_csv("../../data/csv/infrastructure.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8989 entries, 0 to 8988
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          8989 non-null   int64
#  1   ParentLocationCode  8502 non-null   object
#  2   SpatialDim          8989 non-null   object
#  3   Value               8989 non-null   object
#  4   NumericValue        8633 non-null   float64
#  5   TimeDimensionBegin  8989 non-null   object
#  6   TimeDimensionEnd    8989 non-null   object
#  7   TimeDimensionValue  8989 non-null   object
#  8   TimeDimType         8989 non-null   object
#  9   TimeDim             8989 non-null   int64
#  10  IndicatorCode       8989 non-null   object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 772.6+ KB

# %%
df.reset_index(drop=True, inplace=True)
df.columns
# Out:
# Index(['Unnamed: 0', 'ParentLocationCode', 'SpatialDim', 'Value',
#        'NumericValue', 'TimeDimensionBegin', 'TimeDimensionEnd',
#        'TimeDimensionValue', 'TimeDimType', 'TimeDim', 'IndicatorCode'],
#       dtype='object')

# %%
df.describe()
# Out:
#         Unnamed: 0  NumericValue      TimeDim
# count  8989.000000   8633.000000  8989.000000
# mean   4494.000000     51.388152  2012.213706
# std    2595.045118     26.384819     6.739151
# min       0.000000      0.000000  2000.000000
# 25%    2247.000000     29.176521  2007.000000
# 50%    4494.000000     56.000000  2013.000000
# 75%    6741.000000     73.845147  2018.000000
# max    8988.000000    222.685759  2023.000000

# %%
df["IndicatorCode"].unique()
# Out:
# array(['HCF_NO_ELECTRICITY', 'HCF_REL_ELECTRICITY',
#        'HCF_UNREL_ELECTRICITY', 'HRH_40', 'UHC_AVAILABILITY_SCORE',
#        'UHC_INDEX_REPORTED', 'WHS6_102'], dtype=object)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0              0
# ParentLocationCode    487
# SpatialDim              0
# Value                   0
# NumericValue          356
# TimeDimensionBegin      0
# TimeDimensionEnd        0
# TimeDimensionValue      0
# TimeDimType             0
# TimeDim                 0
# IndicatorCode           0
# dtype: int64

# %%
df.drop(columns=["Unnamed: 0"], inplace=True, errors="ignore")
df.dropna(subset="ParentLocationCode", axis = 0, inplace=True)
df.isnull().sum()
# Out:
# ParentLocationCode      0
# SpatialDim              0
# Value                   0
# NumericValue          356
# TimeDimensionBegin      0
# TimeDimensionEnd        0
# TimeDimensionValue      0
# TimeDimType             0
# TimeDim                 0
# IndicatorCode           0
# dtype: int64

# %%
df.info()
df.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8502 entries, 0 to 8988
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ParentLocationCode  8502 non-null   object
#  1   SpatialDim          8502 non-null   object
#  2   Value               8502 non-null   object
#  3   NumericValue        8146 non-null   float64
#  4   TimeDimensionBegin  8502 non-null   object
#  5   TimeDimensionEnd    8502 non-null   object
#  6   TimeDimensionValue  8502 non-null   object
#  7   TimeDimType         8502 non-null   object
#  8   TimeDim             8502 non-null   int64
#  9   IndicatorCode       8502 non-null   object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 730.6+ KB
# Index(['ParentLocationCode', 'SpatialDim', 'Value', 'NumericValue',
#        'TimeDimensionBegin', 'TimeDimensionEnd', 'TimeDimensionValue',
#        'TimeDimType', 'TimeDim', 'IndicatorCode'],
#       dtype='object')

# %%
df["TimeDimensionBegin"] = pd.to_datetime(df["TimeDimensionBegin"], format="ISO8601")
print(df["TimeDimensionBegin"].isnull().value_counts())

df["TimeDimensionEnd"] = pd.to_datetime(df["TimeDimensionEnd"], format="ISO8601")
print(df["TimeDimensionEnd"].isnull().value_counts())

# df["TimeDimensionValue"] = pd.to_datetime(df["TimeDimensionValue"], format="ISO8601")
# print(df["TimeDimensionValue"].isnull().value_counts())

#cột TimeDimensionValue của UHC_AVAILABILITY_SCORE nó là 2019-2023

df.to_csv("infrastructure_data_analysis.csv", index=False)
# Out:
# TimeDimensionBegin
# False    8502
# Name: count, dtype: int64
# TimeDimensionEnd
# False    8502
# Name: count, dtype: int64

# %%
df["IndicatorCode"].unique()
# Out:
# array(['HCF_NO_ELECTRICITY', 'HCF_REL_ELECTRICITY',
#        'HCF_UNREL_ELECTRICITY', 'HRH_40', 'UHC_AVAILABILITY_SCORE',
#        'UHC_INDEX_REPORTED', 'WHS6_102'], dtype=object)

# %%
# HCF_NO_ELECTRICITY : Tỷ lệ (%) cơ sở y tế không có bất kỳ nguồn điện nào.

# HCF_REL_ELECTRICITY : Tỷ lệ (%) cơ sở y tế có nguồn điện ổn định, đáng tin cậy và liên tục.

# HCF_UNREL_ELECTRICITY : Tỷ lệ (%) cơ sở y tế có điện nhưng không ổn định hoặc thường xuyên bị gián đoạn.

# HRH_40 : Mật độ nhân lực y tế (bác sĩ, y tá và hộ sinh) trên mỗi 10.000 dân.

# UHC_AVAILABILITY_SCORE : Điểm thành phần đánh giá mức độ sẵn có và khả năng cung ứng dịch vụ y tế trong hệ thống UHC.

# UHC_INDEX_REPORTED : Chỉ số bao phủ dịch vụ y tế toàn dân (UHC), thang điểm từ 0 đến 100, do quốc gia báo cáo.

# WHS6_102 : Mức độ bao phủ các dịch vụ y tế thiết yếu của hệ thống y tế.
