# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import pearsonr

# %%
df_temp = pd.read_csv("../../data/csv/cholesterol.csv")

# %%
list_IndicatorCode = ["NCD_CHOL_MEANTOTALCHOL_A","NCD_CHOL_MEANNONHDL_A","NCD_CHOL_MEANHDL_A"]
df = df_temp[df_temp["IndicatorCode"].isin(list_IndicatorCode)].copy()

# %%
df.reset_index(drop=True, inplace=True)
df.columns
# Out:
# Index(['Unnamed: 0', 'ParentLocationCode', 'SpatialDim', 'Value',
#        'NumericValue', 'TimeDimensionBegin', 'TimeDimensionEnd',
#        'TimeDimensionValue', 'TimeDimType', 'TimeDim', 'IndicatorCode'],
#       dtype='str')

# %%
df["ParentLocationCode"].info()
# Out:
# <class 'pandas.Series'>
# RangeIndex: 70902 entries, 0 to 70901
# Series name: ParentLocationCode
# Non-Null Count  Dtype
# --------------  -----
# 67041 non-null  str
# dtypes: str(1)
# memory usage: 554.1 KB

# %%
df.describe()
# Out:
#         Unnamed: 0  NumericValue  TimeDimensionValue       TimeDim
# count  70902.00000  70902.000000        70902.000000  70902.000000
# mean   35450.50000      3.066507         1999.000000   1999.000000
# std    20467.78873      1.491752           11.254708     11.254708
# min        0.00000      0.700000         1980.000000   1980.000000
# 25%    17725.25000      1.300000         1989.000000   1989.000000
# 50%    35450.50000      3.400000         1999.000000   1999.000000
# 75%    53175.75000      4.300000         2009.000000   2009.000000
# max    70901.00000      6.200000         2018.000000   2018.000000

# %%
df.describe(include='object')
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_42788\87514550.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include='object')
#        ParentLocationCode SpatialDim          Value  \
# count               67041      70902          70902
# unique                  6        202            922
# top                   EUR        RUS  1.1 [0.9-1.3]
# freq                17901        351           2252
#
#                TimeDimensionBegin           TimeDimensionEnd TimeDimType  \
# count                       70902                      70902       70902
# unique                         39                         39           1
# top     1987-01-01T00:00:00+01:00  1987-12-31T00:00:00+01:00        YEAR
# freq                         1818                       1818       70902
#
#              IndicatorCode
# count                70902
# unique                   3
# top     NCD_CHOL_MEANHDL_A
# freq                 23634

# %%
df.isnull().sum()
# Out:
# Unnamed: 0               0
# ParentLocationCode    3861
# SpatialDim               0
# Value                    0
# NumericValue             0
# TimeDimensionBegin       0
# TimeDimensionEnd         0
# TimeDimensionValue       0
# TimeDimType              0
# TimeDim                  0
# IndicatorCode            0
# dtype: int64

# %%
df.drop(columns=["Unnamed: 0"], inplace=True)

# %%
df.dropna(subset = ["ParentLocationCode"],axis = 0, inplace = True )
df["ParentLocationCode"].isnull().value_counts()
# Out:
# ParentLocationCode
# False    67041
# Name: count, dtype: int64

# %%
df["SpatialDim"].isnull().value_counts()
df["Value"].isnull().value_counts()
# Out:
# Value
# False    67041
# Name: count, dtype: int64

# %%
# df.drop(columns= ["Value"], axis=1 , errors= "ignore", inplace=True)
df.columns
# Out:
# Index(['ParentLocationCode', 'SpatialDim', 'Value', 'NumericValue',
#        'TimeDimensionBegin', 'TimeDimensionEnd', 'TimeDimensionValue',
#        'TimeDimType', 'TimeDim', 'IndicatorCode'],
#       dtype='str')

# %%
df["NumericValue"].isnull().value_counts()
# Out:
# NumericValue
# False    67041
# Name: count, dtype: int64

# %%
# df.drop(columns= ["TimeDimType"], axis=1 , errors= "ignore", inplace=True)

df["TimeDimensionBegin"] = pd.to_datetime(df["TimeDimensionBegin"], format="ISO8601")
print(df["TimeDimensionBegin"].isnull().value_counts())

df["TimeDimensionEnd"] = pd.to_datetime(df["TimeDimensionEnd"], format="ISO8601")
print(df["TimeDimensionEnd"].isnull().value_counts())

df["TimeDimensionValue"] = pd.to_datetime(df["TimeDimensionValue"], format="ISO8601")
print(df["TimeDimensionValue"].isnull().value_counts())

# df.drop(columns= ["TimeDimensionBegin"], axis=1 , errors= "ignore", inplace=True)
# df.drop(columns= ["TimeDimensionEnd"], axis=1 , errors= "ignore", inplace=True)
# df.drop(columns= ["TimeDimensionValue"], axis=1 , errors= "ignore", inplace=True)

print(df.columns)
# Out:
# TimeDimensionBegin
# False    67041
# Name: count, dtype: int64
# TimeDimensionEnd
# False    67041
# Name: count, dtype: int64
# TimeDimensionValue
# False    67041
# Name: count, dtype: int64
# Index(['ParentLocationCode', 'SpatialDim', 'Value', 'NumericValue',
#        'TimeDimensionBegin', 'TimeDimensionEnd', 'TimeDimensionValue',
#        'TimeDimType', 'TimeDim', 'IndicatorCode'],
#       dtype='str')

# %%
print(df["IndicatorCode"].unique())

df["TimeDim"] = pd.to_datetime(df["TimeDim"], format="ISO8601")

df["TimeDim"] = df["TimeDim"].dt.year
df["TimeDim"].unique()
df["TimeDimensionValue"].unique()
# Out:
# <StringArray>
# ['NCD_CHOL_MEANHDL_A', 'NCD_CHOL_MEANNONHDL_A', 'NCD_CHOL_MEANTOTALCHOL_A']
# Length: 3, dtype: str
# <DatetimeArray>
# ['1987-01-01 00:00:00', '2008-01-01 00:00:00', '2015-01-01 00:00:00',
#  '1999-01-01 00:00:00', '1998-01-01 00:00:00', '2001-01-01 00:00:00',
#  '2017-01-01 00:00:00', '1980-01-01 00:00:00', '1981-01-01 00:00:00',
#  '2004-01-01 00:00:00', '2009-01-01 00:00:00', '1982-01-01 00:00:00',
#  '1994-01-01 00:00:00', '2013-01-01 00:00:00', '2014-01-01 00:00:00',
#  '1988-01-01 00:00:00', '1983-01-01 00:00:00', '2016-01-01 00:00:00',
#  '1984-01-01 00:00:00', '2007-01-01 00:00:00', '1991-01-01 00:00:00',
#  '2003-01-01 00:00:00', '2002-01-01 00:00:00', '1990-01-01 00:00:00',
#  '1986-01-01 00:00:00', '1993-01-01 00:00:00', '2010-01-01 00:00:00',
#  '1996-01-01 00:00:00', '2000-01-01 00:00:00', '2011-01-01 00:00:00',
#  '1995-01-01 00:00:00', '1985-01-01 00:00:00', '1992-01-01 00:00:00',
#  '2005-01-01 00:00:00', '2006-01-01 00:00:00', '1989-01-01 00:00:00',
#  '2018-01-01 00:00:00', '2012-01-01 00:00:00', '1997-01-01 00:00:00']
# Length: 39, dtype: datetime64[us]

# %%
plt.figure(figsize=(8,5))
plt.hist(df["NumericValue"].dropna(), bins=30)
plt.title("Histogram: Phân bố NumericValue")
plt.xlabel("Giá trị")
plt.ylabel("Tần suất")
plt.show()

# %%
sns.boxplot(df, x = "IndicatorCode", y = "NumericValue")
plt.xticks(rotation=90);
plt.title("Boxplot: Phân bố NumericValue / IndicatorCode")
# Out:
# Text(0.5, 1.0, 'Boxplot: Phân bố NumericValue / IndicatorCode')

# %%
df['Log_Value'] = np.log1p(df['NumericValue'])
sns.boxplot(data=df, x="IndicatorCode", y="Log_Value")
plt.xticks(rotation=90);
plt.title("Boxplot: Phân bố NumericValue / IndicatorCode (Chuẩn hóa Log)")
# Out:
# Text(0.5, 1.0, 'Boxplot: Phân bố NumericValue / IndicatorCode (Chuẩn hóa Log)')

# %%
for indicator in list_IndicatorCode:
    df_indicator = df[df["IndicatorCode"] == indicator].reset_index(drop=True)
    df_year = (
    df_indicator.groupby("TimeDim")["NumericValue"]
    .mean()
    .reset_index()
    )
    plt.figure(figsize=(10,5))
    plt.plot(df_year["TimeDim"], df_year["NumericValue"], marker="o")
    plt.title(f"LineChart: Xu hướng chỉ số trung bình của {indicator} theo năm")
    plt.xlabel("Năm")
    plt.ylabel("Giá trị trung bình")
    plt.grid(True)
    plt.show()

# %%
# df_country = (
#     df.groupby("SpatialDim")["NumericValue"]
#     .mean()
#     .sort_values(ascending=False)
#     .head(10)
# )

# df_country.plot(kind="bar", figsize=(10,5))
# plt.title("BarChart: Top 10 quốc gia ô nhiễm cao nhất")
# plt.ylabel("Giá trị trung bình")
# plt.show()

# %%
for indicator in list_IndicatorCode:
    df_indicator = df[df["IndicatorCode"] == indicator].reset_index(drop=True)
    pivot = df.pivot_table(
        index="SpatialDim",
        columns="TimeDim",
        values="NumericValue",
        aggfunc="mean"
    )

    plt.figure(figsize=(12,8))
    plt.imshow(pivot, aspect="auto")
    plt.colorbar(label="Giá trị trung bình")
    plt.title(f"Heatmap: Quốc gia × Năm {indicator}")
    plt.xlabel("Năm")
    plt.ylabel("Quốc gia")
    step = 5
    plt.xticks(
    ticks=np.arange(0, len(pivot.columns), step),
    labels=pivot.columns[::step],
    )
    plt.show()

# %%
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import numpy as np  

df["NumericValue"] = pd.to_numeric(df["NumericValue"], errors="coerce")

df_grouped = df[df["IndicatorCode"] == "NCD_CHOL_MEANTOTALCHOL_A"] #lấy chỉ số total_cholesterol

df_grouped = (
    df.groupby(
        ["SpatialDim", "ParentLocationCode", "TimeDim"],
        as_index=False
    )
    .agg(
        MeanValue=("NumericValue", "mean"),
        Count=("NumericValue", "count")
    )
)

df_grouped["LogMeanValue"] = np.log1p(df_grouped["MeanValue"])

world = gpd.read_file("../../worldmap/ne_110m_admin_0_countries.shp")

recent_year = df["TimeDim"].max() #vẽ 5 năm gần nhất

for year in range(recent_year - 4,recent_year + 1):
    df_year = df_grouped[df_grouped["TimeDim"] == year]

    gdf = world.merge(
        df_year,
        how="left",
        left_on="ISO_A3",
        right_on="SpatialDim"
    )

    fig, ax = plt.subplots(figsize=(16, 9))

    gdf.plot(
        column="LogMeanValue",
        ax=ax,
        legend=True,
        cmap="YlOrRd",
        edgecolor="black",
        linewidth=0.3,
        missing_kwds={
            "color": "lightgrey",
            "label": "No data"
        }
    )

    ax.set_title(
        f"Bản đồ nhiệt giá trị trung bình của chỉ số cholesterol – Năm {year}",
        fontsize=16,
        pad=20
    )

    ax.axis("off")
    plt.show()
