# %%
import pandas as pd
import os

# %%
target = 'data'
results = 'results'

# %%
os.makedirs(target, exist_ok=True)
os.makedirs(results, exist_ok=True)

# %%
def extract_indicator():
    folder = os.listdir(target)
    for filename in folder:
        name = filename.split('.')[0]
        object = target + '/' + filename
        
        df = pd.read_csv(object)
        indicators = df['indicator_code'].unique().tolist()

        with open(results + '/' + name + '.txt', 'w', encoding='utf-8'):
            for indicator in indicators:
                f.write(indicator + '\n')

# %%
extract_indicator()
