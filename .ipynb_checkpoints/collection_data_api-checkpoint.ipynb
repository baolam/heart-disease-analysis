# %%
import requests
import json
import pandas as pd
import os
from tqdm import tqdm
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# D:\Anaconda\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
class whoAmI:
    def __init__(self):
        self.getDim='https://ghoapi.azureedge.net/api/Dimension'
        self.getDimValues='https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues'
        self.getIndValues='https://ghoapi.azureedge.net/api/Indicator'
        self.getIndFilterVal='https://ghoapi.azureedge.net/api/Indicator?$filter=contains(IndicatorName,'
        self.getIndFilterSpecVal='https://ghoapi.azureedge.net/api/Indicator?$filter=IndicatorName eq '
        self.getIndData='https://ghoapi.azureedge.net/api/'
urls = whoAmI()

# %%
DATASET_SAVED = "raw_official"
URL_INDICATORS = "urls"

# %%
# Khởi tạo thư mục nếu chưa tồn tại
os.makedirs(DATASET_SAVED, exist_ok=True)
os.makedirs(URL_INDICATORS, exist_ok=True)

# %%
# Lấy các bộ dữ liệu đã có
existed = set()
for file in os.listdir(DATASET_SAVED):
    indicator = file.split('.')[0]
    existed.add(indicator)

# %%
dataset_indicators = set()
for file in os.listdir(URL_INDICATORS):
    with open(URL_INDICATORS + '/' + file, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line in existed:
                continue
            dataset_indicators.add(line)
print("Các indicators:", dataset_indicators)
# Out:
# Các indicators: {'W3_pc_front_C', 'E14b_movies_anti_tob_ads', 'R_admin_covert_marking', 'O_Ins_off_hlth_prof', 'NCD_CCS_TobPlan', 'W21_emissions_A', 'P8_compliance', 'E17b_csr_promo_self', 'R_Price_lowest_cost_estimate', 'P6_compliance', 'R_Ad_val_estimate', 'W21_emissions_quant_B', 'Yth_daily_tob_use', 'TOBACCO_MPOWER_R_TAXSTRUCTURE', 'E22_subnational_authority_exists', 'R_Price_mp_estimate_usd', 'W15_specific_hw_B', 'Rev_import', 'R_afford_price_dispersion', 'W11_outside_pack_A', 'R_earmarking', 'W22_emissions_qual_B', 'R_Curr_premium_cost', 'TOBACCO_MPOWER_M3_TOBACCOUSESMOKINGSCHOOL', 'TOBACCO_MPOWER_O1_TREATMENTSUPPORT', 'W-MM_Group', 'O_Ins_hosp', 'TOBACCO_MPOWER_R_TAXREVENUEPREVIOUS', 'P3_compliance', 'R_contains_nicotine', 'Yth_curr_smokeless', 'E18_csr_anti_tobacco_media', 'W5_top_side_B', 'TOB_R_PRICE', 'P2_compliance', 'Rev_other', 'Adult_daily_e-cig', 'Yth_daily_smokeless', 'R_Price_mp_estimate_ppp', 'P1_healthcare', 'NCD_CCS_TOB_SVY', 'TOBACCO_MPOWER_R_AFFORDABILITY', 'E_compl_e11', 'E12_brand_sharing', 'P12_fines_establishment', 'TOBACCO_MPOWER_R_TAXADMINISTRATION', 'W1_HW_law_B', 'W4_pc_back_C', 'NCD_CHOL_MEANTOTALCHOL_A', 'NTCP_govt_obj', 'R_VAT_estimate', 'Adult_daily_tob_use', 'P6_restaurants', 'P13_fines_smoker', 'W15_specific_hw_C', 'W12_imports_dutyfree_A', 'E11_compliance', 'E_compl_e13', 'W15_specific_hw_A', 'R_admin_duty_free_banned', 'W24_exp_date_A', 'W26_plain_packaging_B', 'Rev_imp_other', 'W5_top_side_C', 'E25_ban_display_pt_of_sale', 'W12_imports_dutyfree_C', 'W20_flavours_B', 'R_Price_premium_usd', 'Yth_daily_e-cig', 'W22_emissions_qual_C', 'O_Avail_community', 'TOBACCO_MPOWER_R_PRICE', 'R_afford_cat', 'W19_colours_numbers_C', 'TOBACCO_MPOWER_NTCP', 'W1_HW_law_A', 'W1_HW_law_C', 'P10_subnat_auth_exists', 'O_Avail_hlth_clin', 'Yth_curr_tob_smoking', 'E12_compliance', 'W19_colours_numbers_B', 'E_compl_e12', 'O_Avail_hosp', 'W16_number_hw_A', 'W20_flavours_C', 'E9_free_distrib', 'W24_exp_date_B', 'R_Price_lowest_cost_ppp', 'NCD_CCS_TOB_MGMT_GUIDE', 'W12_imports_dutyfree_B', 'R_Ad_val_average', 'P15_complaints', 'NCD_CCS_Nicotine', 'W4_pc_back_A', 'E14_compliance', 'P11_fines_any', 'P_count_places_sf', 'E11_brand_stretching', 'R_afford_tax_auto_adjust', 'W8_princ_langs_C', 'R_total_tax_estimate', 'O_Group', 'R_Group', 'W4_pc_back_B', 'W25_quitline_number_B', 'W14_harm_effects_B', 'E15c_sponsor_publicity', 'E24_internet_sales_ban', 'W3_pc_front_A', 'P7_compliance', 'TOBACCO_MPOWER_W1A_CIGARETTES', 'R_excise_incr', 'W_Group', 'E6b_ban_display_pt_of_sale', 'W18_misleading_terms_A', 'TOBACCO_MPOWER_P2_SMOKEFREEPLACEDETAILS', 'R_admin_tax_stamps_cig', 'E21_vending_machines', 'O_Ins_community', 'E14_prod_tv_films', 'E13_brand_placement', 'W2_pc_front_back_B', 'NCD_CHOL_MEANHDL_A', 'E13_compliance', 'Yth_curr_cig_smoking', 'W9_no_obscure_C', 'Adult_curr_e-cig', 'W8_princ_langs_A', 'TOBACCO_MPOWER_M1_TOBACCOUSESMOKING', 'Adult_daily_tob_smoking', 'Camp_gov_prog', 'TOBACCO_MPOWER_W2C_TOBACCOSMOKELESS', 'E_compl_e14', 'Rev_type', 'W14_harm_effects_C', 'W16_number_hw_C', 'TOBACCO_MPOWER_R_EARMARKED', 'R_VAT_average', 'R_Other_estimate', 'W6_font_A', 'W5_top_side_A', 'R_Price_lowest_cost_usd', 'W23_emissions_front_back_C', 'Adult_curr_tob_use', 'TOBACCO_MPOWER_E2_INDIRECTADBANS', 'E17_csr_promo_others', 'E16_csr_promo_self', 'W20_flavours_A', 'M_Group', 'O_NRT_ins', 'W2_pc_front_back_A', 'R_Other_average', 'R_Price_premium_ppp', 'W23_emissions_front_back_B', 'Adult_daily_smokeless', 'W17_fines_A', 'W18_misleading_terms_C', 'R_afford_inflation_adjusted_price_lcu', 'R_Price_premium_estimate', 'Yth_curr_tob_use', 'W13_ind_liability_B', 'W24_exp_date_C', 'TOBACCO_MPOWER_R_INFLATIONADJUSTEDPRICES', 'E14a_prod_tv_films', 'W6_font_B', 'R_afford_inflation_adjusted_price_ppp', 'P9_all_other', 'P14_funds_for_enforce', 'R_Curr_mp', 'Adult_daily_cig_smoking', 'W6_font_C', 'Yth_daily_cig_smoking', 'P_comprehensive_subnat', 'O_Avail_other', 'O_Ins_other', 'NTCP_agcy', 'TOBACCO_MPOWER_W2B_TOBACCOSMOKED', 'R_Price_mp_estimate',  ...

# %%
def request_data(indicator):
    resp = requests.get(urls.getIndData + '/' + indicator)
    data = json.loads(resp.content)["value"]
    fields = ['ParentLocationCode', 'SpatialDim', 'Dim1', 'Value', 'NumericValue', 'Date', 'IndicatorCode']

    records = []
    for row in data:
        _tempo = dict()
        for field in fields:
            _tempo[field] = row[field]
        records.append(_tempo)

    with open(DATASET_SAVED + '/' + indicator + '.json', "w", encoding="utf-8") as f:
        json.dump(records, f, ensure_ascii=False, indent=2)

# %%
# Hàm lấy hết dữ liệu
def retrieve_all():
    for indicator in tqdm(dataset_indicators):
        try:
            request_data(indicator)
        except Exception as e:
            print("Error:", e)

# %%
retrieve_all()
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 261/261 [14:52<00:00,  3.42s/it]

# %%
# Biến chỉ định lưu trữ
CONCAT_GROUP = "raw_concat"
os.makedirs(CONCAT_GROUP, exist_ok=True)

# %%
# Tiến hành tổ chức và nhóm lại dữ liệu vào file gốc theo các nhãn
def prepare_data_through_group(group):
    # Group là nhãn dữ liệu, tên thư mục
    target = group.split('.')[0]
    objectives = set()

    with open(URL_INDICATORS + '/' + group, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            objectives.add(line)
    
    array_data = []
    for file in tqdm(os.listdir(DATASET_SAVED)):
        _label = file.split('.')[0]
        if _label in objectives:
            # Đúng nhãn dữ liệu, tiến hành load ra và ghép lại thành một file hoàn chỉnh
            with open(DATASET_SAVED + '/' + file, "rb") as f:
                data = json.load(f)
                
                # Tiến hành nối dữ liệu vào file
            array_data = array_data + data
                
    concated_result = CONCAT_GROUP + '/' + target + '.json'
    
    print("Tổng số điểm dữ liệu là:", len(array_data))
    with open(concated_result, "w", encoding="utf-8") as f:
        json.dump(array_data, f, ensure_ascii=False, indent=2)
    print("Hoàn thành xử lý:", target)

# %%
# Chạy xử lí chỉ số BMI
prepare_data_through_group("BMI.txt")
# Out:
# 100%|██████████| 285/285 [00:00<00:00, 332.93it/s]
# Tổng số điểm dữ liệu là: 453077
# Hoàn thành xử lý: BMI

# %%
# CHạy xử lí chỉ số Diabetes
prepare_data_through_group("diabetes.txt")
# Out:
# 100%|██████████| 285/285 [00:00<00:00, 490.53it/s]
# Tổng số điểm dữ liệu là: 211564
# Hoàn thành xử lý: diabetes

# %%
# Chạy xử lí tiêu thụ cồn
prepare_data_through_group("alcohol_consumption.txt")
# Out:
# 100%|██████████| 285/285 [00:02<00:00, 100.08it/s]
# Tổng số điểm dữ liệu là: 297817
# Hoàn thành xử lý: alcohol_consumption

# %%
# Chạy xử lí air_pollution
prepare_data_through_group("air_pollution.txt")
# Out:
# 100%|██████████| 285/285 [00:01<00:00, 234.59it/s]
# Tổng số điểm dữ liệu là: 491076
# Hoàn thành xử lý: air_pollution

# %%
# Chạy xử lí cholesterol
prepare_data_through_group("cholesterol.txt")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 546/546 [00:00<00:00, 878.82it/s]
# Tổng số điểm dữ liệu là: 141804
# Hoàn thành xử lý: cholesterol

# %%
# Chạy xử lí Glucose
prepare_data_through_group("glucose.txt")
# Out:
# 100%|██████████| 285/285 [00:00<00:00, 12390.79it/s]
# Tổng số điểm dữ liệu là: 21630
# Hoàn thành xử lý: glucose

# %%
# Chạy xử lí hoạt động thể chất
prepare_data_through_group("physical_activities.txt")
# Out:
# 100%|██████████| 285/285 [00:00<00:00, 4383.04it/s]
# Tổng số điểm dữ liệu là: 35523
# Hoàn thành xử lý: physical_activities

# %%
# Chạy xử lí tiếp cận cơ sở y tế
prepare_data_through_group("infrastructure.txt")
# Out:
# 100%|██████████| 285/285 [00:00<00:00, 913.45it/s]
# Tổng số điểm dữ liệu là: 170916
# Hoàn thành xử lý: infrastructure

# %%
# Chạy xử lí thuốc lá
prepare_data_through_group("tobacco.txt")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 546/546 [00:15<00:00, 34.32it/s]
# Tổng số điểm dữ liệu là: 707018
# Hoàn thành xử lý: tobacco

# %%
# Chạy xử lí bệnh tim mạch
prepare_data_through_group("cardiovascular_diseases.txt")
# Out:
# 100%|██████████| 285/285 [00:00<00:00, 518.06it/s]
# Tổng số điểm dữ liệu là: 236876
# Hoàn thành xử lý: cardiovascular_diseases
