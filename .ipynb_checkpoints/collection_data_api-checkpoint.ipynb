# %%
import requests
import json
import pandas as pd
import os
from tqdm import tqdm
# Out:
# D:\Anaconda\lib\site-packages\pandas\core\computation\expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.8.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# D:\Anaconda\lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
class whoAmI:
    def __init__(self):
        self.getDim='https://ghoapi.azureedge.net/api/Dimension'
        self.getDimValues='https://ghoapi.azureedge.net/api/DIMENSION/COUNTRY/DimensionValues'
        self.getIndValues='https://ghoapi.azureedge.net/api/Indicator'
        self.getIndFilterVal='https://ghoapi.azureedge.net/api/Indicator?$filter=contains(IndicatorName,'
        self.getIndFilterSpecVal='https://ghoapi.azureedge.net/api/Indicator?$filter=IndicatorName eq '
        self.getIndData='https://ghoapi.azureedge.net/api/'
urls = whoAmI()

# %%
DATASET_SAVED = "raw_official"
URL_INDICATORS = "urls"

# %%
# Khởi tạo thư mục nếu chưa tồn tại
os.makedirs(DATASET_SAVED, exist_ok=True)
os.makedirs(URL_INDICATORS, exist_ok=True)

# %%
# Lấy các bộ dữ liệu đã có
existed = set()
for file in os.listdir(DATASET_SAVED):
    indicator = file.split('.')[0]
    existed.add(indicator)

# %%
dataset_indicators = set()
for file in os.listdir(URL_INDICATORS):
    with open(URL_INDICATORS + '/' + file, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            if line in existed:
                continue
            dataset_indicators.add(line)
print("Các indicators:", dataset_indicators)
# Out:
# Các indicators: {'AIR_10', 'AIR_41', 'SA_0000001817', 'AIR_9', 'AIR_75', 'AIR_6', 'WSH_WATER_BASIC', 'NCD_DIABETES_TREATMENT_CRUDE', 'AIR_35', 'NCD_CCS_ALC_TARGET', 'SA_0000001692', 'AIR_74', 'RSUD_480', 'SDGAIRBOD', 'AIR_16', 'SA_0000001841', 'AIR_60', 'AIR_11', 'SA_0000001844', 'AIR_51', 'SA_0000001747', 'AIR_45', 'RSUD_320', 'SDGPM25', 'SA_0000001717', 'RSUD_890', 'AIR_7', 'AIR_8', 'AIR_15', 'SA_0000001402', 'SA_0000001843', 'AIR_62', 'AIR_72', 'AIR_12', 'AIR_71', 'SA_0000001405', 'SA_0000001546', 'AIR_52', 'AIR_46', 'SA_0000001474', 'AIR_17', 'AIR_44', 'SA_0000001398', 'AIR_4', 'SA_0000001691', 'NCD_BMI_30A', 'SA_0000001767', 'SDGAIRBODA', 'SA_0000001833', 'RSUD_740', 'SA_0000001760', 'AIR_73', 'AIR_39', 'AIR_42', 'SA_0000001840', 'RSUD_170', 'SA_0000001554', 'SA_0000001820', 'AIR_5', 'AIR_90', 'AIR_43'}

# %%
def request_data(indicator):
    resp = requests.get(urls.getIndData + '/' + indicator)
    data = json.loads(resp.content)["value"]
    fields = ['ParentLocationCode', 'SpatialDim', 'Dim1', 'Value', 'NumericValue', 'Date', 'IndicatorCode']

    records = []
    for row in data:
        _tempo = dict()
        for field in fields:
            _tempo[field] = row[field]
        records.append(_tempo)

    with open(DATASET_SAVED + '/' + indicator + '.json', "w", encoding="utf-8") as f:
        json.dump(records, f, ensure_ascii=False, indent=2)

# %%
# Hàm lấy hết dữ liệu
def retrieve_all():
    for indicator in tqdm(dataset_indicators):
        try:
            request_data(indicator)
        except Exception as e:

# %%
retrieve_all()
# Out:
#   2%|█▎                                                                                 | 1/61 [00:01<01:06,  1.10s/it]
# Expecting value: line 1 column 1 (char 0)
#   3%|██▋                                                                                | 2/61 [00:02<01:00,  1.03s/it]
# Expecting value: line 1 column 1 (char 0)
#   5%|████                                                                               | 3/61 [00:02<00:55,  1.04it/s]
# Expecting value: line 1 column 1 (char 0)
#   7%|█████▍                                                                             | 4/61 [00:03<00:53,  1.06it/s]
# Expecting value: line 1 column 1 (char 0)
#   8%|██████▊                                                                            | 5/61 [00:04<00:52,  1.07it/s]
# Expecting value: line 1 column 1 (char 0)
#  10%|████████▏                                                                          | 6/61 [00:05<00:51,  1.07it/s]
# Expecting value: line 1 column 1 (char 0)
#  11%|█████████▌                                                                         | 7/61 [00:06<00:50,  1.08it/s]
# Expecting value: line 1 column 1 (char 0)
#  13%|██████████▉                                                                        | 8/61 [00:07<00:48,  1.09it/s]
# Expecting value: line 1 column 1 (char 0)
#  15%|████████████▏                                                                      | 9/61 [00:08<00:47,  1.10it/s]
# Expecting value: line 1 column 1 (char 0)
#  16%|█████████████▍                                                                    | 10/61 [00:09<00:47,  1.08it/s]
# Expecting value: line 1 column 1 (char 0)
#  18%|██████████████▊                                                                   | 11/61 [00:10<00:47,  1.05it/s]
# Expecting value: line 1 column 1 (char 0)
#  20%|████████████████▏                                                                 | 12/61 [00:11<00:47,  1.03it/s]
# Expecting value: line 1 column 1 (char 0)
#  21%|█████████████████▍                                                                | 13/61 [00:12<00:47,  1.02it/s]
# Expecting value: line 1 column 1 (char 0)
#  23%|██████████████████▊                                                               | 14/61 [00:13<00:46,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  25%|████████████████████▏                                                             | 15/61 [00:14<00:45,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  26%|█████████████████████▌                                                            | 16/61 [00:15<00:44,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  28%|██████████████████████▊                                                           | 17/61 [00:16<00:43,  1.00it/s]
# Expecting value: line 1 column 1 (char 0)
#  30%|████████████████████████▏                                                         | 18/61 [00:17<00:42,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  31%|█████████████████████████▌                                                        | 19/61 [00:18<00:41,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  33%|██████████████████████████▉                                                       | 20/61 [00:19<00:41,  1.00s/it]
# Expecting value: line 1 column 1 (char 0)
#  34%|████████████████████████████▏                                                     | 21/61 [00:20<00:40,  1.00s/it]
# Expecting value: line 1 column 1 (char 0)
#  36%|█████████████████████████████▌                                                    | 22/61 [00:21<00:39,  1.00s/it]
# Expecting value: line 1 column 1 (char 0)
#  38%|██████████████████████████████▉                                                   | 23/61 [00:22<00:38,  1.00s/it]
# Expecting value: line 1 column 1 (char 0)
#  39%|████████████████████████████████▎                                                 | 24/61 [00:23<00:36,  1.00it/s]
# Expecting value: line 1 column 1 (char 0)
#  41%|█████████████████████████████████▌                                                | 25/61 [00:24<00:35,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  43%|██████████████████████████████████▉                                               | 26/61 [00:25<00:34,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  44%|████████████████████████████████████▎                                             | 27/61 [00:26<00:33,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  46%|█████████████████████████████████████▋                                            | 28/61 [00:27<00:32,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  48%|██████████████████████████████████████▉                                           | 29/61 [00:28<00:31,  1.02it/s]
# Expecting value: line 1 column 1 (char 0)
#  49%|████████████████████████████████████████▎                                         | 30/61 [00:29<00:30,  1.02it/s]
# Expecting value: line 1 column 1 (char 0)
#  51%|█████████████████████████████████████████▋                                        | 31/61 [00:30<00:29,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  52%|███████████████████████████████████████████                                       | 32/61 [00:31<00:28,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  54%|████████████████████████████████████████████▎                                     | 33/61 [00:32<00:27,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  56%|█████████████████████████████████████████████▋                                    | 34/61 [00:33<00:26,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  57%|███████████████████████████████████████████████                                   | 35/61 [00:34<00:25,  1.00it/s]
# Expecting value: line 1 column 1 (char 0)
#  59%|████████████████████████████████████████████████▍                                 | 36/61 [00:35<00:25,  1.00s/it]
# Expecting value: line 1 column 1 (char 0)
#  61%|█████████████████████████████████████████████████▋                                | 37/61 [00:36<00:23,  1.00it/s]
# Expecting value: line 1 column 1 (char 0)
#  62%|███████████████████████████████████████████████████                               | 38/61 [00:37<00:22,  1.00it/s]
# Expecting value: line 1 column 1 (char 0)
#  64%|████████████████████████████████████████████████████▍                             | 39/61 [00:38<00:21,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  66%|█████████████████████████████████████████████████████▊                            | 40/61 [00:39<00:20,  1.00it/s]
# Expecting value: line 1 column 1 (char 0)
#  67%|███████████████████████████████████████████████████████                           | 41/61 [00:40<00:19,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  69%|████████████████████████████████████████████████████████▍                         | 42/61 [00:41<00:18,  1.02it/s]
# Expecting value: line 1 column 1 (char 0)
#  70%|█████████████████████████████████████████████████████████▊                        | 43/61 [00:42<00:17,  1.02it/s]
# Expecting value: line 1 column 1 (char 0)
#  72%|███████████████████████████████████████████████████████████▏                      | 44/61 [00:43<00:16,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)
#  74%|████████████████████████████████████████████████████████████▍                     | 45/61 [00:44<00:16,  1.00s/it]
# Expecting value: line 1 column 1 (char 0)
#  75%|█████████████████████████████████████████████████████████████▊                    | 46/61 [00:45<00:15,  1.00s/it]
# Expecting value: line 1 column 1 (char 0)
#  77%|███████████████████████████████████████████████████████████████▏                  | 47/61 [00:46<00:14,  1.00s/it]
# Expecting value: line 1 column 1 (char 0)
#  79%|████████████████████████████████████████████████████████████████▌                 | 48/61 [00:47<00:13,  1.04s/it]
# Expecting value: line 1 column 1 (char 0)
#  80%|█████████████████████████████████████████████████████████████████▊                | 49/61 [00:48<00:12,  1.04s/it]
# Expecting value: line 1 column 1 (char 0)
#  82%|███████████████████████████████████████████████████████████████████▏              | 50/61 [00:49<00:11,  1.03s/it]
# Expecting value: line 1 column 1 (char 0)
#  84%|████████████████████████████████████████████████████████████████████▌             | 51/61 [00:50<00:10,  1.03s/it]
# Expecting value: line 1 column 1 (char 0)
#  85%|█████████████████████████████████████████████████████████████████████▉            | 52/61 [00:51<00:09,  1.02s/it]
# Expecting value: line 1 column 1 (char 0)
#  87%|███████████████████████████████████████████████████████████████████████▏          | 53/61 [00:52<00:08,  1.02s/it]
# Expecting value: line 1 column 1 (char 0)
#  89%|████████████████████████████████████████████████████████████████████████▌         | 54/61 [00:53<00:07,  1.01s/it]
# Expecting value: line 1 column 1 (char 0)
#  90%|█████████████████████████████████████████████████████████████████████████▉        | 55/61 [00:54<00:06,  1.02s/it]
# Expecting value: line 1 column 1 (char 0)
#  92%|███████████████████████████████████████████████████████████████████████████▎      | 56/61 [00:55<00:05,  1.02s/it]
# Expecting value: line 1 column 1 (char 0)
#  93%|████████████████████████████████████████████████████████████████████████████▌     | 57/61 [00:56<00:04,  1.02s/it]
# Expecting value: line 1 column 1 (char 0)
#  95%|█████████████████████████████████████████████████████████████████████████████▉    | 58/61 [00:57<00:03,  1.02s/it]
# Expecting value: line 1 column 1 (char 0)
#  97%|███████████████████████████████████████████████████████████████████████████████▎  | 59/61 [00:58<00:02,  1.02s/it]
# Expecting value: line 1 column 1 (char 0)
#  98%|████████████████████████████████████████████████████████████████████████████████▋ | 60/61 [00:59<00:01,  1.01s/it]
# Expecting value: line 1 column 1 (char 0)
# 100%|██████████████████████████████████████████████████████████████████████████████████| 61/61 [01:00<00:00,  1.01it/s]
# Expecting value: line 1 column 1 (char 0)

# %%
# Biến chỉ định lưu trữ
CONCAT_GROUP = "raw_concat"
os.makedirs(CONCAT_GROUP, exist_ok=True)

# %%
# Tiến hành tổ chức và nhóm lại dữ liệu vào file gốc theo các nhãn
def prepare_data_through_group(group):
    # Group là nhãn dữ liệu, tên thư mục
    target = group.split('.')[0]
    objectives = set()

    with open(URL_INDICATORS + '/' + group, "r", encoding="utf-8") as f:
        for line in f:
            line = line.strip()
            objectives.add(line)
    
    array_data = []
    for file in tqdm(os.listdir(DATASET_SAVED)):
        _label = file.split('.')[0]
        if _label in objectives:
            # Đúng nhãn dữ liệu, tiến hành load ra và ghép lại thành một file hoàn chỉnh
            with open(DATASET_SAVED + '/' + file, "rb") as f:
                data = json.load(f)
                
                # Tiến hành nối dữ liệu vào file
            array_data = array_data + data
                
    concated_result = CONCAT_GROUP + '/' + target + '.json'
    
    print("Tổng số điểm dữ liệu là:", len(array_data))
    with open(concated_result, "w", encoding="utf-8") as f:
        json.dump(array_data, f, ensure_ascii=False, indent=2)
    print("Hoàn thành xử lý:", target)

# %%
# Chạy xử lí chỉ số BMI
prepare_data_through_group("BMI.txt")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 178/178 [00:01<00:00, 102.34it/s]
# Tổng số điểm dữ liệu là: 432287
# Hoàn thành xử lý: BMI

# %%
# CHạy xử lí chỉ số Diabetes
prepare_data_through_group("diabetes.txt")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████| 178/178 [00:01<00:00, 159.17it/s]
# Tổng số điểm dữ liệu là: 190774
# Hoàn thành xử lý: diabetes

# %%
# Chạy xử lí tiêu thụ cồn
prepare_data_through_group("alcohol_consumption.txt")
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 178/178 [00:05<00:00, 34.19it/s]
# Tổng số điểm dữ liệu là: 250720
# Hoàn thành xử lý: alcohol_consumption
